# %% [markdown]
# <a href="https://colab.research.google.com/github/chandan110791/Agentic_AI_Playground/blob/main/1_Basic_agent_run_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chandan110791/Agentic_AI_Playground.git
# Out:
# Cloning into 'Agentic_AI_Playground'...
# remote: Enumerating objects: 441, done.
# remote: Counting objects: 100% (441/441), done.
# remote: Compressing objects: 100% (261/261), done.
# remote: Total 441 (delta 153), reused 424 (delta 147), pack-reused 0 (from 0)
# Receiving objects: 100% (441/441), 150.71 KiB | 8.87 MiB/s, done.
# Resolving deltas: 100% (153/153), done.

# %%
import os
os.chdir("/content/Agentic_AI_Playground/1-basic-agent")
# !ls -a -lrt
# Out:
# total 20
# -rw-r--r--  1 root root 4593 Feb  9 07:23 README.md
# drwxr-xr-x  2 root root 4096 Feb  9 07:23 greeting_agent
# drwxr-xr-x  3 root root 4096 Feb  9 07:23 .
# drwxr-xr-x 16 root root 4096 Feb  9 07:23 ..

# %%
from pathlib import Path
from google.colab import userdata
Path(".env").write_text(f"GOOGLE_API_KEY={userdata.get("GOOGLE_API_KEY").strip()}")
# Out:
# 54

# %%
os.chmod(".env", 0o600)

# %%
# !nohup adk web . --host 0.0.0.0 --port 8000 > /content/adk.log & echo $! > /contet/adk_pid
# Out:
# /bin/bash: line 1: /contet/adk_pid: No such file or directory
# nohup: redirecting stderr to stdout

# %%
from google.colab import output
output.serve_kernel_port_as_window(8000)
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.

# %%
# !kill -SIGINT $(lsof -i :8000 | awk 'NR>1 {print $2}')
