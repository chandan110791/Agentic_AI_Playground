# %% [markdown]
# <a href="https://colab.research.google.com/github/chandan110791/Agentic_AI_Playground/blob/main/P2_LoopSequentialLinkedPost_run_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chandan110791/Agentic_AI_Playground.git
# Out:
# Cloning into 'Agentic_AI_Playground'...
# remote: Enumerating objects: 550, done.
# remote: Counting objects: 100% (550/550), done.
# remote: Compressing objects: 100% (328/328), done.
# remote: Total 550 (delta 201), reused 512 (delta 174), pack-reused 0 (from 0)
# Receiving objects: 100% (550/550), 163.62 KiB | 1.31 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %%
# !cd /content/Agentic_AI_Playground
# !git fetch origin
# !git reset --hard origin/main
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 739 bytes | 739.00 KiB/s, done.
# From https://github.com/chandan110791/Agentic_AI_Playground
#    14a085f..ed8d6b7  main       -> origin/main
# HEAD is now at ed8d6b7 changes

# %%
# !pip install -r /content/Agentic_AI_Playground/requirements.txt
# Out:
# ...
# WARNING: google-adk 1.23.0 does not provide the extra 'database'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 102.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 19.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.1
#     Uninstalling python-dotenv-1.2.1:
#       Successfully uninstalled python-dotenv-1.2.1
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.66
#     Uninstalling yfinance-0.2.66:
#       Successfully uninstalled yfinance-0.2.66
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.6
#     Uninstalling google-generativeai-0.8.6:
#       Successfully uninstalled google-generativeai-0.8.6
# ...

# %%
import os
os.chdir("/content/Agentic_AI_Playground/P2_LoopAgent_linkedPost")
# !ls -a -lrt
# Out:
# total 32
# drwxr-xr-x 17 root root  4096 Feb  9 12:05 ..
# drwxr-xr-x  3 root root  4096 Feb  9 12:05 .adk
# drwxr-xr-x  4 root root  4096 Feb  9 12:05 .
# drwxr-xr-x  7 root root  4096 Feb  9 12:06 linkedPostagent
# -rw-------  1 root root    54 Feb  9 12:34 .env
# -rw-r--r--  1 root root 22999 Feb  9 12:34 1

# %%
from pathlib import Path
from google.colab import userdata
Path(".env").write_text(f"GOOGLE_API_KEY={userdata.get("GOOGLE_API_KEY").strip()}")
# Out:
# 54

# %%
os.chmod(".env", 0o600)

# %%
# !nohup adk web . --host 0.0.0.0 --port 8000 > /content/adk.log 2>1& echo $! > /content/adk_pid

# %%
from google.colab import output
output.serve_kernel_port_as_window(8000)
# Out:
# ...
# Try `serve_kernel_port_as_iframe` instead.

# %%
# !kill -SIGINT $(lsof -i :8000 | awk 'NR>1 {print $2}')
